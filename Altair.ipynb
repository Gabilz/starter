# %%
import pandas as pd
import altair as alt

df = pd.read_csv("/chile-bibliotecas - chile-bibliotecas.csv.csv")

df.head()
# Out:
#                        Nombre    Región         Comuna  \
# 0  Biblioteca Pública 305 BC1  Tarapacá  Alto Hospicio
# 1  Biblioteca Pública 326 BC1  Tarapacá          Huara
# 2  Biblioteca Pública 340 BC1  Tarapacá          Huara
# 3  Biblioteca Pública 211 BC1  Tarapacá        Iquique
# 4  Biblioteca Pública 214 BC1  Tarapacá        Iquique
#
#                                    Dirección                 Contacto  \
# 0                    Avenida Los Alamos 3020        Maria Nieves Coca
# 1                      Avenida Esmeralda s/n    Marcia Paola Passache
# 2                      Calle Arturo Prat s/n  Ricardo Antonio Demetri
# 3                 Avenida Pedro Gamboni 2850     Silvana Zoila Flores
# 4  Avenida 12 de febrero 1802 / Libertad 909     Carmen Clelia Vernal
#
#       Teléfono                  Correo Capacitaciones Préstamos  \
# 0  988866420.0  b305bc1@abretumundo.cl             SI        SI
# 1  988109500.0  b326bc1@abretumundo.cl             NO        SI
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import altair as alt

df = pd.read_csv(/mnt/sample_data/1.cvs)

df.head()
# Out:
#   File "<ipython-input-13-ab9d0fc3ccc8>", line 4
#     df = pd.read_csv(/mnt/sample_data/1.cvs)
#     ^
# IndentationError: unexpected indent

# %%
# Out:
#   File "<ipython-input-13-ab9d0fc3ccc8>", line 4
#     df = pd.read_csv(/mnt/sample_data/1.cvs)
#     ^
# IndentationError: unexpected indent
